# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Get the data into kernel

# %%
mcd_df = pd.read_csv("menu.csv")
pd.set_option('display.max_columns', None) ## Forces pandas to diaplay the full table
mcd_df.head(3)
# Out:
#     Category               Item    Serving Size  Calories  Calories from Fat  \
# 0  Breakfast       Egg McMuffin  4.8 oz (136 g)       300                120
# 1  Breakfast  Egg White Delight  4.8 oz (135 g)       250                 70
# 2  Breakfast   Sausage McMuffin  3.9 oz (111 g)       370                200
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0       13.0                         20            5.0
# 1        8.0                         12            3.0
# 2       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 0                             25        0.0          260
# 1                             15        0.0           25
# 2                             42        0.0           45
#
#    Cholesterol (% Daily Value)  Sodium  Sodium (% Daily Value)  Carbohydrates  \
# 0                           87     750                      31             31
# ...

# %%
mcd_df.columns.values
# Out:
# array(['Category', 'Item', 'Serving_Size', 'Calories', 'Calories_Fat',
#        'Total_Fat', 'Total_Fat_Per', 'Saturated_Fat', 'Saturated_Fat_Per',
#        'Trans_Fat', 'Cholesterol', 'Cholesterol_Per', 'Sodium',
#        'Sodium_Per', 'Carbohydrates', 'Carbohydrates_Per', 'Dietary_Fiber',
#        'Dietary_Fiber_Per', 'Sugars', 'Protein', 'Vitamin_A_Per',
#        'Vitamin_C_Per', 'Calcium_Per', 'Iron_Per'], dtype=object)

# %%
mcd_df = mcd_df.rename(columns={'Serving Size': 'Serving_Size',
                                'Calories from Fat': 'Calories_Fat',
                                'Total Fat':'Total_Fat', 
                                'Total Fat (% Daily Value)':'Total_Fat_Per', 
                                'Saturated Fat':'Saturated_Fat',
                                'Saturated Fat (% Daily Value)':'Saturated_Fat_Per', 
                                'Trans Fat':'Trans_Fat', 
                                'Cholesterol (% Daily Value)':'Cholesterol_Per', 
                                'Sodium (% Daily Value)':'Sodium_Per',
                                'Carbohydrates (% Daily Value)':'Carbohydrates_Per',
                                'Dietary Fiber':'Dietary_Fiber',
                                'Dietary Fiber (% Daily Value)':'Dietary_Fiber_Per', 
                                'Vitamin A (% Daily Value)':'Vitamin_A_Per', 
                                'Vitamin C (% Daily Value)':'Vitamin_C_Per',
                                'Calcium (% Daily Value)':'Calcium_Per', 
                                'Iron (% Daily Value)':'Iron_Per'})

# %%
mcd_df.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_Fat  Total_Fat  Total_Fat_Per  \
# 255  10.1 oz (285 g)       510           150       17.0             26
# 256  13.4 oz (381 g)       690           200       23.0             35
# 257   6.7 oz (190 g)       340           100       11.0             17
# 258  14.2 oz (403 g)       810           290       32.0             50
# 259   7.1 oz (202 g)       410           150       16.0             25
#
#      Saturated_Fat  Saturated_Fat_Per  Trans_Fat  Cholesterol  \
# ...

# %%
mcd_df['Ser_Size_Solid'] = mcd_df['Serving_Size'].str.extract('((... g))', expand =True)
mcd_df['Ser_Size_Solid'] = mcd_df['Ser_Size_Solid'].str.extract('(...)', expand = True)
mcd_df['Ser_Size_Solid'].head()
# Out:
# 0    136
# 1    135
# 2    111
# 3    161
# 4    161
# Name: Ser_Size_Solid, dtype: object

# %%
mcd_df['Ser_Size_Liquid'] = mcd_df['Serving_Size'].str.extract('()', expand =True)
#mcd_df['Ser_Size_Solid'] = mcd_df['Ser_Size_Solid'].str.extract('(...)', expand = True)
mcd_df['Ser_Size_Liquid'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Ser_Size_Liquid, dtype: object

# %%
j = mcd_df[mcd_df['Category'] == 'Smoothies & Shakes']
j.head()
# Out:
#                Category                                     Item  \
# 232  Smoothies & Shakes   Blueberry Pomegranate Smoothie (Small)
# 233  Smoothies & Shakes  Blueberry Pomegranate Smoothie (Medium)
# 234  Smoothies & Shakes   Blueberry Pomegranate Smoothie (Large)
# 235  Smoothies & Shakes       Strawberry Banana Smoothie (Small)
# 236  Smoothies & Shakes      Strawberry Banana Smoothie (Medium)
#
#      Serving_Size  Calories  Calories_Fat  Total_Fat  Total_Fat_Per  \
# 232  12 fl oz cup       220             5        0.5              1
# 233  16 fl oz cup       260             5        1.0              1
# 234  22 fl oz cup       340            10        1.0              2
# 235  12 fl oz cup       210             5        0.5              1
# 236  16 fl oz cup       250             5        1.0              1
#
#      Saturated_Fat  Saturated_Fat_Per  Trans_Fat  Cholesterol  \
# 232            0.0                  0        0.0            5
# ...

# %%
def SayHello():
print ('Hello!! how are you')
# Out:
#   File "<ipython-input-4-1db12903321c>", line 2
#     print ('Hello!! how are you')
#         ^
# IndentationError: expected an indented block
