# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
toys = pd.read_csv("new_amazon_web_analysis.csv", encoding='latin1')

# %%
toys.head(1)
# Out:
#    Unnamed: 0           product_name manufacturer price  \
# 0           0  Hornby 2014 Catalogue       Hornby  3.42
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
#
#                                              sellers amaz_cat
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...  Hobbies

# %%
plt.figure(figsize=[20,20])
sns.countplot(data=toys,x='amaz_cat')
plt.xticks(rotation=90, size =17)
plt.show()

# %%
toys['amaz_cat'].unique()
# Out:
# array(['Hobbies', 'o', 'Characters & Brands', 'Fancy Dress', 'Bags',
#        'Arts & Crafts', 'Handbags & Shoulder Bags', 'Games',
#        'Figures & Playsets', 'Home Accessories', 'Sweets, Chocolate & Gum',
#        'Sports Toys & Outdoor', 'Die-Cast & Toy Vehicles',
#        'Baby & Toddler Toys', 'Storage, Cleaning & Ring Sizers',
#        'Bedding & Linens', 'Office Supplies', 'Party Supplies',
#        'Camping & Hiking', 'Pretend Play', 'Women', 'Electronic Toys',
#        'Car Parts', 'Dolls & Accessories', 'Indoor Lighting',
#        'Educational Toys', 'Laundry, Storage & Organisation',
#        "Supporters' Gear", 'Jams, Honey & Spreads',
#        'Novelty & Special Use', 'Musical Toy Instruments', 'Men',
#        'Sex & Sensuality', 'Cooking & Dining', 'Medication & Remedies',
#        'Puppets & Puppet Theatres', 'Jigsaws & Puzzles', 'Dogs',
#        'Medical Supplies & Equipment', 'Pens, Pencils & Writing Supplies',
#        'Worlds Apart', 'Gardening', 'Lab & Scientific Products',
#        'Novelty Jewellery'], dtype=object)

# %%
catag = ['Hobbies', 'Characters & Brands', 'Fancy Dress', 'Bags',
       'Arts & Crafts', 'Handbags & Shoulder Bags', 'Games',
       'Figures & Playsets', 'Home Accessories', 'Sweets, Chocolate & Gum',
       'Sports Toys & Outdoor', 'Die-Cast & Toy Vehicles',
       'Baby & Toddler Toys', 'Storage, Cleaning & Ring Sizers',
       'Bedding & Linens', 'Office Supplies', 'Party Supplies',
       'Camping & Hiking', 'Pretend Play', 'Women', 'Electronic Toys',
       'Car Parts', 'Dolls & Accessories', 'Indoor Lighting',
       'Educational Toys', 'Laundry, Storage & Organisation',
       "Supporters' Gear", 'Jams, Honey & Spreads',
       'Novelty & Special Use', 'Musical Toy Instruments', 'Men',
       'Sex & Sensuality', 'Cooking & Dining', 'Medication & Remedies',
       'Puppets & Puppet Theatres', 'Jigsaws & Puzzles', 'Dogs',
       'Medical Supplies & Equipment', 'Pens, Pencils & Writing Supplies',
       'Worlds Apart', 'Gardening', 'Lab & Scientific Products',
       'Novelty Jewellery']
count = []
name = []
for i in catag:
    new_ctag = toys[toys['amaz_cat'] == i]
    cnt = new_ctag.amaz_cat.count()
    if (cnt >=100):
        count.append(cnt)
        name.append(i)

dfa = {'Name': pd.Series(name),
      'Count': pd.Series(count)}
df = pd.DataFrame(dfa)
print(df)
sns.barplot(data=df,x='Name',y='Count')
plt.xticks(rotation =90, size = 17)
plt.show()
# Out:
#     Count                       Name
# 0    1464                    Hobbies
# 1     960        Characters & Brands
# 2     585                Fancy Dress
# 3     802              Arts & Crafts
# 4     941                      Games
# 5    1111         Figures & Playsets
# 6     372      Sports Toys & Outdoor
# 7    1221    Die-Cast & Toy Vehicles
# 8     106        Baby & Toddler Toys
# 9     694             Party Supplies
# 10    371        Dolls & Accessories
# 11    269  Puppets & Puppet Theatres
# 12    274          Jigsaws & Puzzles

# %%
hobbies_df = toys[toys['amaz_cat'] == 'Hobbies']
hobbies_df = hobbies_df.drop(['Unnamed: 0'], axis =1)
hobbies_df.head(1)
# Out:
#             product_name manufacturer price number_available_in_stock  \
# 0  Hornby 2014 Catalogue       Hornby  3.42                     5 new
#
#   number_of_reviews  number_of_answered_questions average_review_rating  \
# 0                15                           1.0    4.9 out of 5 stars
#
#                     amazon_category_and_sub_category  \
# 0  ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
#
#                                              sellers amaz_cat
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...  Hobbies

# %%
hobbies_df['amazon_category_and_sub_category'] = hobbies_df['amazon_category_and_sub_category'].str.split(',')

# %%
counter = []
numb = []
for i in range(0,len(hobbies_df['amazon_category_and_sub_category'])):
    b = len(hobbies_df['amazon_category_and_sub_category'].iloc[i])
    counter.append(b)
    numb.append(i)
    
daf ={'Number': pd.Series(counter),
     'Count': pd.Series(numb)}
df = pd.DataFrame(daf)
sns.countplot(data=df, x= 'Number')
plt.show()

# %%
hobbies_df.head(1)
# Out:
#             product_name manufacturer price number_available_in_stock  \
# 0  Hornby 2014 Catalogue       Hornby  3.42                     5 new
#
#   number_of_reviews  number_of_answered_questions average_review_rating  \
# 0                15                           1.0    4.9 out of 5 stars
#
#                     amazon_category_and_sub_category  \
# 0  [['Hobbies',  'Model Trains & Railway Sets',  ...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
#
#                                              sellers amaz_cat  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...  Hobbies
#
#                         hobbies_2         hobbies_3   hobbies_4 hobbies_5
# 0   'Model Trains & Railway Sets'   'Rail Vehicles'   'Trains']

# %%
hobbies_df['hobbies_2'] = ''

for i in range(0,len(hobbies_df['amazon_category_and_sub_category'])):
    if (len(hobbies_df['amazon_category_and_sub_category'].iloc[i]) >=2):
        hobbies_df['hobbies_2'].iloc[i] = hobbies_df['amazon_category_and_sub_category'].iloc[i][1]

hobbies_df['hobbies_3'] = ''

for i in range(0,len(hobbies_df['amazon_category_and_sub_category'])):
    if (len(hobbies_df['amazon_category_and_sub_category'].iloc[i]) >=3):
        hobbies_df['hobbies_3'].iloc[i] = hobbies_df['amazon_category_and_sub_category'].iloc[i][2]
        
        
hobbies_df['hobbies_4'] = ''

for i in range(0,len(hobbies_df['amazon_category_and_sub_category'])):
    if (len(hobbies_df['amazon_category_and_sub_category'].iloc[i]) >=4):
        hobbies_df['hobbies_4'].iloc[i] = hobbies_df['amazon_category_and_sub_category'].iloc[i][3]
        
hobbies_df['hobbies_5'] = ''

for i in range(0,len(hobbies_df['amazon_category_and_sub_category'])):
    if (len(hobbies_df['amazon_category_and_sub_category'].iloc[i]) == 5):
        hobbies_df['hobbies_5'].iloc[i] = hobbies_df['amazon_category_and_sub_category'].iloc[i][4]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
hobbies_df['hobbies_2'] = hobbies_df['hobbies_2'].str.strip('\'').str.replace('\'','')
hobbies_df['hobbies_3'] = hobbies_df['hobbies_3'].str.strip('\'').str.replace('\'','')

hobbies_df['hobbies_4'] = hobbies_df['hobbies_4'].str.strip('\'').str.replace('\'','').str.replace(']','')

hobbies_df['hobbies_5'] = hobbies_df['hobbies_5'].str.strip('\'').str.replace('\'','').str.replace(']','')
# Out:
#   File "<ipython-input-13-0c6dc6361965>", line 2
#     hobbies_df['hobbies_3'] = hobbies_df['hobbies_3'].str.strip('\'').str.replace('\'','')str.replace(']','')
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
hobbies_df.hobbies_2.unique()
# Out:
# array([' Model Trains & Railway Sets', ' Model Building Kits',
#        ' Collectible Figures & Memorabilia', ' Slot Cars',
#        ' Remote Controlled Devices', ' Trading Cards & Accessories'], dtype=object)

# %%
hob_2 =[' Model Trains & Railway Sets', ' Model Building Kits',
       ' Collectible Figures & Memorabilia', ' Slot Cars',
       ' Remote Controlled Devices', ' Trading Cards & Accessories']
count = []
hobb_2 = []
for i in hob_2:
    xyz =  hobbies_df[hobbies_df['hobbies_2'] == i]
    cnt =  xyz.hobbies_2.count()
    hobb_2.append(i)
    count.append(cnt)
    

dsa = {'count': pd.Series(count),
    'hob2': pd.Series(hobb_2)
      }
df = pd.DataFrame(dsa)
print(df)
sns.barplot(data=df,x='hob2',y='count')
plt.xticks(rotation = 90, size = 17)
plt.show()
# Out:
#    count                                hob2
# 0    387         Model Trains & Railway Sets
# 1    174                 Model Building Kits
# 2    139   Collectible Figures & Memorabilia
# 3    184                           Slot Cars
# 4    203           Remote Controlled Devices
# 5    377         Trading Cards & Accessories

# %% [markdown]
# #### in hobbies >>  Model Trains & Railway Sets and Trading Cards & Accessories has more number of takers. we dig deeper.

# %%
hobbies_df.head(1)
# Out:
#             product_name manufacturer price number_available_in_stock  \
# 0  Hornby 2014 Catalogue       Hornby  3.42                     5 new
#
#   number_of_reviews  number_of_answered_questions average_review_rating  \
# 0                15                           1.0    4.9 out of 5 stars
#
#                     amazon_category_and_sub_category  \
# 0  [['Hobbies',  'Model Trains & Railway Sets',  ...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
#
#                                              sellers amaz_cat  \
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...  Hobbies
#
#                       hobbies_2       hobbies_3 hobbies_4 hobbies_5
# 0   Model Trains & Railway Sets   Rail Vehicles    Trains
