# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pylab as plt
# %matplotlib inline

h = sorted([186, 176, 158, 180, 186, 168, 168, 164, 178, 170, 189, 195, 172,
     187, 180, 186, 185, 168, 179, 178, 183, 179, 170, 175, 186, 159,
     161, 178, 175, 185, 175, 162, 173, 172, 177, 175, 172, 177, 180])

fit = stats.norm.pdf(h, np.mean(h), np.std(h))
nit = stats.norm.cdf(h, np.mean(h), np.std(h))
plt.plot(h,fit,'-o',color = 'r')
plt.plot(h,nit,'-o',color = 'b')
#plt.hist(h,normed=True,rwidth = 0.8, color ='b')

plt.show()

# %%
import seaborn as sns
sns.distplot(h, kde = True, hist = False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
np.max(h)
# Out:
# 195

# %%
np.min(h)
# Out:
# 158

# %%
k = sorted (np.random.randint(10,20,500))

# %%
fitt = stats.norm.pdf(k, np.mean(k), np.std(k))
nitt = stats.norm.cdf(k, np.mean(k), np.std(k))
plt.plot(k,fitt,'-o',color = 'r')
plt.plot(k,nitt,'-o',color = 'b')
#plt.hist(k,normed = True ,rwidth = 0.8, bins = 10)
plt.show()

# %%
fitt = stats.norm.(l)
plt.plot(k,fitt,'-o',color = 'r')
plt.show()

# %%
np.median(k)
# Out:
# 4.7436706888315516

# %%
k
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19]
